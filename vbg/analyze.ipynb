# %%
# import pandas as pd
# df1 = pd.read_csv("sampleA-(1, 1, 0.1)_bt.csv")
# df2 = pd.read_csv("sampleA-(2, 1, 0.1)_bt.csv")
# df3 = pd.read_csv("sampleA-(3, 1, 0.1)_bt.csv")
# df4 = pd.read_csv("sampleA-(4, 1, 0.1)_bt.csv")
# df5 = pd.read_csv("sampleA-(5, 1, 0.1)_bt.csv")

# %%
df1_a_cnt = df1.groupby(['episode']).max()
df2_a_cnt = df2.groupby(['episode']).max()
df3_a_cnt = df3.groupby(['episode']).max()
df4_a_cnt = df4.groupby(['episode']).max()
df5_a_cnt = df5.groupby(['episode']).max()

# %%
data = pd.concat([df1_a_cnt,df2_a_cnt,df3_a_cnt,df4_a_cnt,df5_a_cnt,])

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(8,5))
data_x=np.arange(1,201)
c='green'
a=0.2
plt.ylabel('Steps to the goal')
plt.xlim(0,201)
plt.fill_between(data_x,data.groupby(['episode'])['a_cnt'].min(),data.groupby(['episode'])['a_cnt'].max(),color=c,alpha=a)
data.groupby(['episode'])['a_cnt'].mean().plot(color='green')
data.groupby(['episode'])['a_cnt'].max().plot(linestyle="dashed",alpha=a,color='green')
data.groupby(['episode'])['a_cnt'].min().plot(linestyle="dashed",alpha=a,color='green')
plt.xlabel('Episode')
# Out:
# Text(0.5, 0, 'Episode')

# %%
import numpy as np

data_x=np.arange(1,201)
plt.figure(figsize=(8,5))
plt.xlim(0,200)
a=0.8
plt.xlabel('Episode')
plt.ylabel('Maximum activity of dopamine cells')
plt.fill_between(data_x,df5.groupby(['episode'])['DA56D'].max(), alpha=a,color='pink',label='(3,4), Down')
plt.fill_between(data_x,df5.groupby(['episode'])['DA55R'].max(), alpha=a,color='tomato',label='(3,3), Right')
plt.fill_between(data_x,df5.groupby(['episode'])['DA54R'].max(), alpha=a,color='gold',label='(3,2), Right')
plt.fill_between(data_x,df5.groupby(['episode'])['DA53R'].max(), alpha=a,color='mediumseagreen',label='(3,1), Right')
plt.fill_between(data_x,df5.groupby(['episode'])['DA43D'].max(), alpha=a,color='lightseagreen',label='(2,1), Down')
plt.fill_between(data_x,df5.groupby(['episode'])['DA42R'].max(), alpha=a,color='cornflowerblue',label='(2,0), Right')
plt.fill_between(data_x,df5.groupby(['episode'])['DA32D'].max(), alpha=a,color='orchid',label='(1,0), Down')
plt.fill_between(data_x,df5.groupby(['episode'])['DA22D'].max(), alpha=a,color='grey',label='(0,0), Down')
plt.legend()

# %%
import pandas as pd

df1 = pd.read_csv("sampleA-1.csv")
df2 = pd.read_csv("sampleA-2.csv")
df3 = pd.read_csv("sampleA-3.csv")
df4 = pd.read_csv("sampleA-4.csv")
df5 = pd.read_csv("sampleA-5.csv")
df6 = pd.read_csv("sampleA-6.csv")
df7 = pd.read_csv("sampleA-7.csv")
df8 = pd.read_csv("sampleA-8.csv")
df9 = pd.read_csv("sampleA-9.csv")
df10 = pd.read_csv("sampleA-10.csv")
df11 = pd.read_csv("sampleA-11.csv")
df12 = pd.read_csv("sampleA-12.csv")
df13 = pd.read_csv("sampleA-13.csv")
df14 = pd.read_csv("sampleA-14.csv")
df15 = pd.read_csv("sampleA-15.csv")
df16 = pd.read_csv("sampleA-16.csv")
df17 = pd.read_csv("sampleA-17.csv")
df18 = pd.read_csv("sampleA-18.csv")
df19 = pd.read_csv("sampleA-19.csv")
df20 = pd.read_csv("sampleA-20.csv")

# %%
import pandas as pd
df1 = pd.read_csv("sampleA-1.csv")

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.subplots_adjust(wspace=0.4, hspace=0.6)
plt.figure(figsize=(10,10))
data_x=np.arange(1,201)
a=1
c='black'
n=1

file_name = df1

for i in range(2,9):
    for j in range(2,9):
        plt.subplot(7,7,n)
        plt.scatter
        plt.xticks(color="None")
        plt.yticks(color="None")
        plt.ylim(0,1.1)
        file_name.groupby(['episode'])['DA{}{}'.format(i,j)].max().plot(color=c)
        plt.fill_between(data_x,file_name.groupby(['episode'])['DA{}{}'.format(i,j)].max(), alpha=a,color=c)
        n+=1

# %%
import numpy as np
plt.subplots_adjust(wspace=0.4, hspace=0.6)
plt.figure(figsize=(10,10))
data_x=np.arange(1,201)
a=1
c='black'
n=1
file_name = df1

for i in range(2,7):
    for j in range(2,7):
        plt.subplot(5,5,n)
        plt.scatter
        plt.xticks(color="None")
        plt.yticks(color="None")
        plt.ylim(0,1.1)
        file_name.groupby(['episode'])['DA{}{}R'.format(i,j)].max().plot(color=c)
        plt.fill_between(data_x,file_name.groupby(['episode'])['DA{}{}R'.format(i,j)].max(), alpha=a,color=c)
        n+=1

# %%
import numpy as np
plt.subplots_adjust(wspace=0.4, hspace=0.6)
plt.figure(figsize=(10,10))
data_x=np.arange(1,201)
a=1
c='black'
n=1
for i in range(2,7):
    for j in range(2,7):
        plt.subplot(5,5,n)
        plt.scatter
        plt.xticks(color="None")
        plt.yticks(color="None")
        plt.ylim(0,1.1)
        df5.groupby(['episode'])['DA{}{}L'.format(i,j)].max().plot(color=c)
        plt.fill_between(data_x,df5.groupby(['episode'])['DA{}{}L'.format(i,j)].max(), alpha=a,color=c)
        n+=1

# %%
import numpy as np
plt.subplots_adjust(wspace=0.4, hspace=0.6)
plt.figure(figsize=(10,10))
data_x=np.arange(1,201)
a=1
c='black'
n=1
for i in range(2,7):
    for j in range(2,7):
        plt.subplot(5,5,n)
        plt.scatter
        plt.xticks(color="None")
        plt.yticks(color="None")
        plt.ylim(0,1.1)
        df5.groupby(['episode'])['DA{}{}D'.format(i,j)].max().plot(color=c)
        plt.fill_between(data_x,df5.groupby(['episode'])['DA{}{}D'.format(i,j)].max(), alpha=a,color=c)
        n+=1

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
plt.subplots_adjust(wspace=0.4, hspace=0.6)
plt.figure(figsize=(10,10))
data_x=np.arange(1,201)
a=1
c='black'
n=1
for i in range(2,7):
    for j in range(2,7):
        plt.subplot(5,5,n)
        plt.scatter
        plt.xticks(color="None")
        plt.yticks(color="None")
        plt.ylim(0,1.1)
        df5.groupby(['episode'])['DA{}{}U'.format(i,j)].max().plot(color=c)
        plt.fill_between(data_x,df5.groupby(['episode'])['DA{}{}U'.format(i,j)].max(), alpha=a,color=c)
        df5.groupby(['episode'])['DA{}{}R'.format(i,j)].max().plot(color=c)
        plt.fill_between(data_x,df5.groupby(['episode'])['DA{}{}R'.format(i,j)].max(), alpha=a,color=c)
        df5.groupby(['episode'])['DA{}{}L'.format(i,j)].max().plot(color=c)
        plt.fill_between(data_x,df5.groupby(['episode'])['DA{}{}L'.format(i,j)].max(), alpha=a,color=c)
        df5.groupby(['episode'])['DA{}{}D'.format(i,j)].max().plot(color=c)
        plt.fill_between(data_x,df5.groupby(['episode'])['DA{}{}D'.format(i,j)].max(), alpha=a,color=c)
        n+=1

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(8,5))
data_x=np.arange(1,201)
plt.ylabel('Maximum activity')
plt.fill_between(data_x,df5.groupby(['episode'])['DA56D'].max(), alpha=0.7,color='gold')
df5.groupby(['episode'])['DA56D'].max().plot(color='gold',label='Dopamin')
(1+(df5.groupby(['episode'])['gl_hyper66D'].max()-df5.groupby(['episode'])['gl_gpe66D'].min()-1.1)).plot(color='tomato',label='Reward + HyperDirect(Global) + Indirect(Global)')
(-df5.groupby(['episode'])['strio56D'].min()).plot(color='cornflowerblue',label='HyperDirect - Direct + Indirect')
plt.xlabel('Episode')
plt.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(8,5))
data_x=np.arange(1,201)
plt.ylabel('Maximum activity')
plt.fill_between(data_x,df5.groupby(['episode'])['DA53R'].max(), alpha=0.7,color='gold')
df5.groupby(['episode'])['DA53R'].max().plot(color='gold',label='Dopamin')
(5*(df5.groupby(['episode'])['gl_hyper54R'].max()-df5.groupby(['episode'])['gl_gpe54R'].min()-1.1)).plot(color='tomato',label='Reward + HyperDirect(Global) + Indirect(Global)')
(-(df5.groupby(['episode'])['strio53R'].max()-5*(df5.groupby(['episode'])['gl_hyper54R'].max()-df5.groupby(['episode'])['gl_gpe54R'].min()-1.1))).plot(color='cornflowerblue',label='HyperDirect - Direct + Indirect')
plt.xlabel('Episode')
plt.legend()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df0 = pd.read_csv('sampleA-(0, 1, 0.1).csv')
dfh = df0.groupby(['episode'])['H'].max()
dfd1 = df0.groupby(['episode'])['D1'].min()
dfd2 = df0.groupby(['episode'])['D2'].min()
df = pd.merge(pd.DataFrame(dfh), pd.DataFrame(dfd1), on='episode')
df = pd.merge(pd.DataFrame(df), pd.DataFrame(dfd2), on='episode')
sns.stripplot(data=df)
plt.show()

# %%
import seaborn as sns

df0 = pd.read_csv('sampleA-(0, 1, 0.5).csv')
dfh = df0.groupby(['episode'])['H'].max()
dfd1 = df0.groupby(['episode'])['D1'].min()
dfd2 = df0.groupby(['episode'])['D2'].max()
df = pd.merge(pd.DataFrame(dfh), pd.DataFrame(dfd1), on='episode')
df = pd.merge(pd.DataFrame(df), pd.DataFrame(dfd2), on='episode')
sns.stripplot(data=df)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.subplots_adjust(wspace=0.4, hspace=0.6)
plt.figure(figsize=(10,10))
data_x=np.arange(1,201)
a=1
c='black'
n=1
for i in range(2,7):
    for j in range(2,7):
        plt.subplot(5,5,n)
        plt.scatter
        plt.xticks(color="None")
        plt.yticks(color="None")
        plt.ylim(0,1.1)
        (1-df5.groupby(['episode'])['SNr{}{}SU'.format(i,j)].max()).plot(color=c)
        n+=1

# %%
import numpy as np
plt.subplots_adjust(wspace=0.4, hspace=0.6)
plt.figure(figsize=(10,10))
data_x=np.arange(1,201)
a=1
c='black'
n=1
for i in range(2,7):
    for j in range(2,7):
        plt.subplot(5,5,n)
        plt.scatter
        plt.xticks(color="None")
        plt.yticks(color="None")
        plt.ylim(0,1.1)
        (1-df5.groupby(['episode'])['SNr{}{}SR'.format(i,j)].max()).plot(color=c)
        plt.fill_between(data_x,(1-df5.groupby(['episode'])['SNr{}{}SR'.format(i,j)].max()), alpha=a,color=c)
        n+=1

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.subplots_adjust(wspace=0.4, hspace=0.6)
plt.figure(figsize=(10,10))
data_x=np.arange(1,201)
a=1
c='black'
n=1
for i in range(2,7):
    for j in range(2,7):
        plt.subplot(5,5,n)
        plt.scatter
        plt.xticks(color="None")
        plt.yticks(color="None")
        plt.ylim(0,1.1)
        (1-df5.groupby(['episode'])['SNr{}{}SL'.format(i,j)].max()).plot(color=c)
        n+=1

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.subplots_adjust(wspace=0.4, hspace=0.6)
plt.figure(figsize=(10,10))
data_x=np.arange(1,201)
a=1
c='black'
n=1
for i in range(2,7):
    for j in range(2,7):
        plt.subplot(5,5,n)
        plt.scatter
        plt.xticks(color="None")
        plt.yticks(color="None")
        plt.ylim(0,1.1)
        (1-df5.groupby(['episode'])['SNr{}{}SD'.format(i,j)].max()).plot(color=c)
        plt.fill_between(data_x,(1-df5.groupby(['episode'])['SNr{}{}SD'.format(i,j)].max()), alpha=a,color=c)
        n+=1
